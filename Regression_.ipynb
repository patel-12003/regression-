# %% [markdown]
# ## Regression
#
# # What is Simple Linear Regression?
# Ans: Simple linear regression is a statistical method used to model the relationship between two variables. It assumes that one variable (the dependent variable-y) is linearly dependent on another variable (the independent variable -X).
#
#
# # What are the key assumptions of Simple Linear Regression?
# Ans: Linearity,Independence,Homoscedasticity,Normality of Errors these are the asssumptions of simple linear regression.
#
# # What does the coefficient m represent in the equation Y=mX+c?
# Ans: the coefficient m represents the slope in the given equation.
#
# # What does the intercept c represent in the equation Y=mX+c?
# Ans: c is the intercept, and it represents the value of Y when X is equal to zero.
#
# #  How do we calculate the slope m in Simple Linear Regression?
# Ans: the slpoe m is calculated by y2-y1/x2-x1 in simple linear regression.
#
# # What is the purpose of the least squares method in Simple Linear Regression?
# Ans: The least squares method in Simple Linear Regression is used to find the best-fitting line that minimizes the difference between the observed data points and the predicted values from the model.
#
# #  How is the coefficient of determination (R²) interpreted in Simple Linear Regression?
# Ans: The coefficient of determination, denoted as R² (R-squared), is a key statistical measure used to assess the goodness of fit of a regression model, particularly in simple linear regression.
#
# #  What is Multiple Linear Regression?
# Ans: Multiple Linear Regression contains more than one independent variable to predict a dependent variable.
#
# # What is the main difference between Simple and Multiple Linear Regression?
# Ans: The main difference between Simple Linear Regression and Multiple Linear Regression lies in the number of independent variables used to predict the dependent variable.
#
# # What are the key assumptions of Multiple Linear Regression?
# Ans: Linearity
# Independence
# Homoscedasticity
# Normality of Errors
# No Multicollinearity
# No Autocorrelation of Errors
#
# # What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model?
# Ans: Heteroscedasticity is the condition where the variability of the residuals (errors) is not constant across the levels of the independent variables.
#
# #  How can you improve a Multiple Linear Regression model with high multicollinearity?
# Ans: Remove One of the Correlated Variables
#       Combine Correlated Variables
#       Increase Sample Size
#
#
# # What are some common techniques for transforming categorical variables for use in regression models?
# Ans: One-Hot Encoding
#      Label Encoding
#
# # What is the role of interaction terms in Multiple Linear Regression?
# Ans: In Multiple Linear Regression (MLR), interaction terms play a crucial role by capturing the combined effect of two or more predictors on the dependent variable that cannot be explained by the individual predictors alone.
#
# # How can the interpretation of intercept differ between Simple and Multiple Linear Regression?
# Ans: nterpretation can differ significantly between Simple Linear Regression and Multiple Linear Regression, primarily due to the number of predictors and the nature of the relationships being modeled.
#
# # What is the significance of the slope in regression analysis, and how does it affect predictions?
# Ans: The slope in regression analysis is a key component of the model that indicates the relationship between the independent variable(s) (predictor) and the dependent variable (outcome). It represents the rate of change of the dependent variable as the independent variable changes.
#
# # How does the intercept in a regression model provide context for the relationship between variables?
# Ans:  the intercept gives us an important baseline reference point for understanding this relationship.
#
# # What are the limitations of using R² as a sole measure of model performance?
# Ans: Misleading with complex models
#      Doesn't penalize overfitting
#      Inapplicable to non-linear relationships.
#
#
#
# # How would you interpret a large standard error for a regression coefficient?
# Ans: A large standard error for a regression coefficient suggests that the estimate of the coefficient is unstable or imprecise.
#
#
# # How can heteroscedasticity be identified in residual plots, and why is it important to address it?
# Ans: Identifying heteroscedasticity in residual plots is crucial because it indicates that the assumption of constant variance of errors is violated, which can lead to inefficient estimates, invalid statistical tests, and unreliable predictions.
#
#
# # What does it mean if a Multiple Linear Regression model has a high R² but low adjusted R²?
# Ans: When a Multiple Linear Regression model has a high R² but a low adjusted R², it typically suggests that the model is overfitting the data.
#
# # Why is it important to scale variables in Multiple Linear Regression?
# Ans: Scaling variables in Multiple Linear Regression is important for several reasons, primarily related to improving the model's performance, interpretation, and the efficiency of the estimation process.
#
# # What is polynomial regression?
# Ans: Polynomial regression is a type of linear regression where the relationship between the independent variabl X and the dependent variable Y is modeled as an nth-degree polynomial rather than a straight line.
#
# #  How does polynomial regression differ from linear regression?
# Ans: Polynomial regression and linear regression are both types of regression models used to model relationships between variables, but they differ significantly in how they handle the relationship between the independent variable and the dependent variable.
#
#
# # When is polynomial regression used?
# Ans: Polynomial regression is used when the relationship between the independent variable(s) and the dependent variable is nonlinear.
#
# # What is the general equation for polynomial regression?
# ans:
#
#
# #Can polynomial regression be applied to multiple variables?
# Ans: yes
#
# #  What are the limitations of polynomial regression?
# Ans: Overfitting
#      Extrapolation Issues
#      Multicollinearity
#      Complexity with Multiple Variables.
#
#
# # What methods can be used to evaluate model fit when selecting the degree of a polynomial?
# Ans: Cross-Validation
#      Adjusted R²
#      MSE / RMSE.
#
#
# # Why is visualization important in polynomial regression?
# Ans: Understand the Data and the Relationship
#      Identify Overfitting
#      Evaluate ResidualsDetermine the Optimal Degree.
#
#
# #  How is polynomial regression implemented in Python?
# Ans: using the scikit-learn library.
